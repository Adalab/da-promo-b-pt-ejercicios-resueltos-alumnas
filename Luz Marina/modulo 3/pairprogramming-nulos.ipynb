# %%
import pandas as pd
import numpy as np 

from sklearn.impute import SimpleImputer
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.impute import KNNImputer

pd.set_option('display.max_columns',None)

# %%
#1.Cargad el csv.
df = pd.read_csv("../files/merchant_fill.csv")

# %%
#2.¿Qué columnas tienen nulos?
df.isnull().sum()
# Out:
# Unnamed: 0                       0
# title                            0
# price                            0
# retail_price                     0
# units_sold                       0
# uses_ad_boosts                   0
# rating_sold                      0
# rating_count                     0
# rating_five_count               45
# rating_four_count               45
# rating_three_count              45
# rating_two_count                45
# rating_one_count                45
# badge_local_product              0
# badge_product_quality            0
# badge_fast_shipping              0
# tags                             0
# product_color                   41
# product_variation_size_id       14
# shipping_option_name             0
# shipping_option_price            0
# shipping_is_express              0
# countries_shipped_to             0
# inventory_total                  0
# origin_country                  17
# merchant_name                    4
# merchant_info_subtitle         294
# ...

# %%
#3.Explorad los nulos que hay en el DataFrame.
nulos = df.isnull().sum()[df.isnull().sum() > 0]
nulos
# Out:
# rating_five_count             45
# rating_four_count             45
# rating_three_count            45
# rating_two_count              45
# rating_one_count              45
# product_color                 41
# product_variation_size_id     14
# origin_country                17
# merchant_name                  4
# merchant_info_subtitle       294
# dtype: int64

# %%
(df.isnull().sum()[df.isnull().sum() > 0]/df.shape[0]*100).round(2)
# Out:
# rating_five_count             2.86
# rating_four_count             2.86
# rating_three_count            2.86
# rating_two_count              2.86
# rating_one_count              2.86
# product_color                 2.61
# product_variation_size_id     0.89
# origin_country                1.08
# merchant_name                 0.25
# merchant_info_subtitle       18.69
# dtype: float64

# %%
#4.Con lo aprendido en la lección de hoy gestiona los nulos de la forma que consideres más correcta.
#las dos que apenas tienen nulos se los eliminamos
df_clean = df.dropna()

df_clean = df.drop(columns=['merchant_name','product_variation_size_id'])

# %%
#rating tienen la misma cantidad de nulos por lo que vamos a hacer una imputacion

imputer = IterativeImputer(max_iter=10, random_states =42)
imputer_rating =imputer.fit_transform(df[['rating_five_count','rating_four_count']])
df['rating_five_count','rating_four_count'] = imputer_rating
#rating_three_count            2.86
#rating_two_count              2.86
#rating_one_count
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 3
#       1 #rating tienen la misma cantidad de nulos por lo que vamos a hacer una imputacion
# ----> 3 imputer = IterativeImputer(max_iter=10, random_states =42)
#       4 imputer_rating =imputer.fit_transform(df[['rating_five_count']])
#       5 df['rating_five_count'] = imputer_rating
#
# TypeError: IterativeImputer.__init__() got an unexpected keyword argument 'random_states'

# %%
#5.Guarda el csv con las columnas sin nulos.
