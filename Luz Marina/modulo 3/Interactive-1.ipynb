# %% [markdown]
# Connected to Python 3.11.9

# %%
import pandas as pd 
import numpy as np

#Leer los archivos CSV (ventas.csv, productos.csv, clientes.csv).
df_ventas = pd.read_csv("../files/ventas.csv")
df_ventas.head()
# Out:
#    ID_Cliente ID_Producto Fecha_Venta  Cantidad  Total
# 0         723          A1  2023-11-22         2  17.98
# 1         498          C3  2023-11-21         1   5.49
# 2         121          D4  2023-11-20         3  32.97
# 3         885         L12  2023-11-19         1   6.49
# 4         347         Q17  2023-11-18         2   7.98

# %%
df_ventas.isnull().sum()
# Out:
# ID_Cliente     0
# ID_Producto    0
# Fecha_Venta    0
# Cantidad       0
# Total          0
# dtype: int64

# %%
df_productos = pd.read_csv("../files/productos.csv",on_bad_lines='skip')
df_productos.head()
# Out:
#                         ID    Nombre_Producto  Categoría  Precio  \
# A1        Pizza Margherita  Platos Preparados       8.99  Italia
# B2  Risotto de Champiñones  Platos Preparados       6.75  Italia
# C3                Tiramisú            Postres       5.49  Italia
# D4               Panettone         Repostería      10.99  Italia
# E5             Orecchiette    Productos Secos       4.29  Italia
#
#                                                Origen  \
# A1                  Clásica pizza italiana con tomate
# B2            Risotto cremoso con champiñones frescos
# C3  Postre clásico italiano con capas de bizcocho ...
# D4  Pan dulce navideño italiano con frutas confita...
# E5  Pequeñas pastas con forma de orecchiette ideal...
#
#                                       Descripción
# A1                  mozzarella fresca y albahaca.
# B2   una delicia italiana para disfrutar en casa.
# C3                   mascarpone y cacao en polvo.
# D4               un regalo tradicional en Italia.
# E5                                            NaN

# %%
df_ventas.info()


df_productos.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID_Cliente   100 non-null    int64
#  1   ID_Producto  100 non-null    object
#  2   Fecha_Venta  100 non-null    object
#  3   Cantidad     100 non-null    int64
#  4   Total        100 non-null    float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.0+ KB
# ID                 0
# Nombre_Producto    0
# Categoría          0
# Precio             0
# Origen             0
# Descripción        1
# dtype: int64

# %%
df_clientes = pd.read_csv("../files/clientes.csv")
df_clientes.head()

df_clientes.isnull().sum()
# Out:
# id              0
# first_name      0
# last_name       0
# email          27
# gender         77
# City          124
# Country       154
# Address        41
# dtype: int64

# %%
df_clientes = pd.read_csv("../files/clientes.csv")
df_clientes.head()
# Out:
#    id  first_name last_name                         email  gender  \
# 0   1       Cheri  Dunsmore      cdunsmore0@instagram.com  Female
# 1   2        Hunt  Bartomeu         hbartomeu1@nsw.gov.au    Male
# 2   3  Michaeline   Paynton            mpaynton2@narod.ru  Female
# 3   4      Filmer    Eirwin            feirwin3@intel.com     NaN
# 4   5      Tanhya   Lubbock  tlubbock4@huffingtonpost.com  Female
#
#                           City Country                   Address
# 0            Palma De Mallorca   Spain  076 Rockefeller Crossing
# 1                         Lugo   Spain        0046 Utah Junction
# 2                          NaN   Spain          0 Corry Crossing
# 3                         Leon   Spain       5 American Ash Road
# 4  Hospitalet De Llobregat, L'   Spain         9289 Merry Circle

# %%
df_clientes.isnull().sum()
# Out:
# id              0
# first_name      0
# last_name       0
# email          27
# gender         77
# City          124
# Country       154
# Address        41
# dtype: int64

# %%
df_clientes.columns()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\Luzma\Desktop\Adalab\modulo 3\pairprogramin\pairprogramming-ELT.py:2
#       1 # %%
# ----> 2 df_clientes.columns()
#
# TypeError: 'Index' object is not callable

# %%
df_clientes.columns
# Out:
# Index(['id', 'first_name', 'last_name', 'email', 'gender', 'City', 'Country',
#        'Address'],
#       dtype='object')

# %%
df_productos.isnull().sum()
# Out:
# ID                 0
# Nombre_Producto    0
# Categoría          0
# Precio             0
# Origen             0
# Descripción        1
# dtype: int64

# %%
df_productos['Descripción'] = df_productos['Descripción'].replace(999,np.nan)

# %%
df_productos.isnull().sum()
# Out:
# ID                 0
# Nombre_Producto    0
# Categoría          0
# Precio             0
# Origen             0
# Descripción        1
# dtype: int64

# %%
df_productos = pd.read_csv("../files/productos.csv",on_bad_lines='skip')
df_productos.head()
# Out:
#                         ID    Nombre_Producto  Categoría  Precio  \
# A1        Pizza Margherita  Platos Preparados       8.99  Italia
# B2  Risotto de Champiñones  Platos Preparados       6.75  Italia
# C3                Tiramisú            Postres       5.49  Italia
# D4               Panettone         Repostería      10.99  Italia
# E5             Orecchiette    Productos Secos       4.29  Italia
#
#                                                Origen  \
# A1                  Clásica pizza italiana con tomate
# B2            Risotto cremoso con champiñones frescos
# C3  Postre clásico italiano con capas de bizcocho ...
# D4  Pan dulce navideño italiano con frutas confita...
# E5  Pequeñas pastas con forma de orecchiette ideal...
#
#                                       Descripción
# A1                  mozzarella fresca y albahaca.
# B2   una delicia italiana para disfrutar en casa.
# C3                   mascarpone y cacao en polvo.
# D4               un regalo tradicional en Italia.
# E5                                            NaN

# %%
df_clientes = pd.read_csv("../files/clientes.csv")
df_clientes.head()
# Out:
#    id  first_name last_name                         email  gender  \
# 0   1       Cheri  Dunsmore      cdunsmore0@instagram.com  Female
# 1   2        Hunt  Bartomeu         hbartomeu1@nsw.gov.au    Male
# 2   3  Michaeline   Paynton            mpaynton2@narod.ru  Female
# 3   4      Filmer    Eirwin            feirwin3@intel.com     NaN
# 4   5      Tanhya   Lubbock  tlubbock4@huffingtonpost.com  Female
#
#                           City Country                   Address
# 0            Palma De Mallorca   Spain  076 Rockefeller Crossing
# 1                         Lugo   Spain        0046 Utah Junction
# 2                          NaN   Spain          0 Corry Crossing
# 3                         Leon   Spain       5 American Ash Road
# 4  Hospitalet De Llobregat, L'   Spain         9289 Merry Circle

# %%
df_clientes["gender"].unique()
# Out:
# array(['Female', 'Male', nan, 'Polygender', 'Genderfluid', 'Non-binary',
#        'Agender', 'Bigender', 'Genderqueer'], dtype=object)

# %%
df_clientes.isnull().sum()
# Out:
# id              0
# first_name      0
# last_name       0
# email          27
# gender         77
# City          124
# Country       154
# Address        41
# dtype: int64

# %%
df_clientes.shape
# Out:
# (1000, 8)

# %%
(df_clientes.isnull().sum())/1000
# Out:
# id            0.000
# first_name    0.000
# last_name     0.000
# email         0.027
# gender        0.077
# City          0.124
# Country       0.154
# Address       0.041
# dtype: float64

# %%
((df_clientes.isnull().sum())/1000)*100
# Out:
# id             0.0
# first_name     0.0
# last_name      0.0
# email          2.7
# gender         7.7
# City          12.4
# Country       15.4
# Address        4.1
# dtype: float64

# %%
df_productos.isnull("city")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\Luzma\Desktop\Adalab\modulo 3\pairprogramin\pairprogramming-ELT.py:2
#       1 # %%
# ----> 2 df_productos.isnull("city")
#
# TypeError: DataFrame.isnull() takes 1 positional argument but 2 were given

# %%
df_productos.isnull("City")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\Luzma\Desktop\Adalab\modulo 3\pairprogramin\pairprogramming-ELT.py:2
#       1 # %%
# ----> 2 df_productos.isnull("City")
#
# TypeError: DataFrame.isnull() takes 1 positional argument but 2 were given

# %%
df_productos.isnull(["City"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\Luzma\Desktop\Adalab\modulo 3\pairprogramin\pairprogramming-ELT.py:2
#       1 # %%
# ----> 2 df_productos.isnull(["City"])
#
# TypeError: DataFrame.isnull() takes 1 positional argument but 2 were given

# %%
filas_con_nulos = df_clientes[df_clientes['City'].isnull()]

# %%
filas_con_nulos = df_clientes[df_clientes['City'].isnull()]
filas_con_nulos
# Out:
#       id  first_name    last_name                      email  gender City  \
# 2      3  Michaeline      Paynton         mpaynton2@narod.ru  Female  NaN
# 8      9       Tymon      Darragh          tdarragh8@free.fr    Male  NaN
# 10    11       Chase  Godilington   cgodilingtona@spiegel.de    Male  NaN
# 18    19        Sena     MacElane        smacelanei@youtu.be  Female  NaN
# 32    33      Adoree      Cutchey       acutcheyw@seesaa.net     NaN  NaN
# ..   ...         ...          ...                        ...     ...  ...
# 942  943     Maritsa        Doale         mdoaleq6@google.nl     NaN  NaN
# 961  962     Domenic        Adger          dadgerqp@time.com    Male  NaN
# 964  965      Marijn     St Clair  mstclairqs@technorati.com    Male  NaN
# 965  966        Didi       Hawtry   dhawtryqt@opensource.org  Female  NaN
# 986  987       Cecil        Hemms  chemmsre@reverbnation.com    Male  NaN
#
#     Country               Address
# 2     Spain      0 Corry Crossing
# 8     Spain      41 Trailsway Way
# 10      NaN     13 Bluestem Court
# 18    Spain  8032 Claremont Trail
# 32    Spain     917 Marcy Parkway
# ..      ...                   ...
# 942   Spain        7 Toban Center
# 961   Spain  327 Gateway Crossing
# 964   Spain          57 Jay Drive
# 965   Spain       901 Packers Way
# 986   Spain  1737 Commercial Lane
#
# [124 rows x 8 columns]

# %%
filas_con_nulos = df_clientes[df_clientes['City'].isnull()]
filas_con_nulos
# Out:
#       id  first_name    last_name                      email  gender City  \
# 2      3  Michaeline      Paynton         mpaynton2@narod.ru  Female  NaN
# 8      9       Tymon      Darragh          tdarragh8@free.fr    Male  NaN
# 10    11       Chase  Godilington   cgodilingtona@spiegel.de    Male  NaN
# 18    19        Sena     MacElane        smacelanei@youtu.be  Female  NaN
# 32    33      Adoree      Cutchey       acutcheyw@seesaa.net     NaN  NaN
# ..   ...         ...          ...                        ...     ...  ...
# 942  943     Maritsa        Doale         mdoaleq6@google.nl     NaN  NaN
# 961  962     Domenic        Adger          dadgerqp@time.com    Male  NaN
# 964  965      Marijn     St Clair  mstclairqs@technorati.com    Male  NaN
# 965  966        Didi       Hawtry   dhawtryqt@opensource.org  Female  NaN
# 986  987       Cecil        Hemms  chemmsre@reverbnation.com    Male  NaN
#
#     Country               Address
# 2     Spain      0 Corry Crossing
# 8     Spain      41 Trailsway Way
# 10      NaN     13 Bluestem Court
# 18    Spain  8032 Claremont Trail
# 32    Spain     917 Marcy Parkway
# ..      ...                   ...
# 942   Spain        7 Toban Center
# 961   Spain  327 Gateway Crossing
# 964   Spain          57 Jay Drive
# 965   Spain       901 Packers Way
# 986   Spain  1737 Commercial Lane
#
# [124 rows x 8 columns]

# %%
filas_con_nulos = df_clientes[df_clientes['City'].isnull()]
filas_con_nulos
# Out:
#       id  first_name    last_name                      email  gender City  \
# 2      3  Michaeline      Paynton         mpaynton2@narod.ru  Female  NaN
# 8      9       Tymon      Darragh          tdarragh8@free.fr    Male  NaN
# 10    11       Chase  Godilington   cgodilingtona@spiegel.de    Male  NaN
# 18    19        Sena     MacElane        smacelanei@youtu.be  Female  NaN
# 32    33      Adoree      Cutchey       acutcheyw@seesaa.net     NaN  NaN
# ..   ...         ...          ...                        ...     ...  ...
# 942  943     Maritsa        Doale         mdoaleq6@google.nl     NaN  NaN
# 961  962     Domenic        Adger          dadgerqp@time.com    Male  NaN
# 964  965      Marijn     St Clair  mstclairqs@technorati.com    Male  NaN
# 965  966        Didi       Hawtry   dhawtryqt@opensource.org  Female  NaN
# 986  987       Cecil        Hemms  chemmsre@reverbnation.com    Male  NaN
#
#     Country               Address
# 2     Spain      0 Corry Crossing
# 8     Spain      41 Trailsway Way
# 10      NaN     13 Bluestem Court
# 18    Spain  8032 Claremont Trail
# 32    Spain     917 Marcy Parkway
# ..      ...                   ...
# 942   Spain        7 Toban Center
# 961   Spain  327 Gateway Crossing
# 964   Spain          57 Jay Drive
# 965   Spain       901 Packers Way
# 986   Spain  1737 Commercial Lane
#
# [124 rows x 8 columns]

# %%
filas_con_nulos = df_clientes[df_clientes['City'].isnull()]
filas_con_nulos
# Out:
#       id  first_name    last_name                      email  gender City  \
# 2      3  Michaeline      Paynton         mpaynton2@narod.ru  Female  NaN
# 8      9       Tymon      Darragh          tdarragh8@free.fr    Male  NaN
# 10    11       Chase  Godilington   cgodilingtona@spiegel.de    Male  NaN
# 18    19        Sena     MacElane        smacelanei@youtu.be  Female  NaN
# 32    33      Adoree      Cutchey       acutcheyw@seesaa.net     NaN  NaN
# ..   ...         ...          ...                        ...     ...  ...
# 942  943     Maritsa        Doale         mdoaleq6@google.nl     NaN  NaN
# 961  962     Domenic        Adger          dadgerqp@time.com    Male  NaN
# 964  965      Marijn     St Clair  mstclairqs@technorati.com    Male  NaN
# 965  966        Didi       Hawtry   dhawtryqt@opensource.org  Female  NaN
# 986  987       Cecil        Hemms  chemmsre@reverbnation.com    Male  NaN
#
#     Country               Address
# 2     Spain      0 Corry Crossing
# 8     Spain      41 Trailsway Way
# 10      NaN     13 Bluestem Court
# 18    Spain  8032 Claremont Trail
# 32    Spain     917 Marcy Parkway
# ..      ...                   ...
# 942   Spain        7 Toban Center
# 961   Spain  327 Gateway Crossing
# 964   Spain          57 Jay Drive
# 965   Spain       901 Packers Way
# 986   Spain  1737 Commercial Lane
#
# [124 rows x 8 columns]
