# %%
import pandas as pd 
import numpy as np 
# Librerías de visualización
# -----------------------------------------------------------------------
import seaborn as sns
import matplotlib.pyplot as plt
from itertools import combinations

# %%
df = pd.read_csv("../files/merchant_fill_nonulls.csv")

# %%
#1.La variable price representa el precio de los productos. 
# Calcula tanto la media como la mediana de los precios y explica la diferencia entre ambas medidas.
# Proporciona ejemplos de situaciones en las que la mediana podría ser preferible sobre la media.

df_prices_media = df["price"].mean()
df_prices_media
# Out:
# 8.325371900826447

# %%
df_prices_mediana = df["price"].median()
df_prices_mediana
# Out:
# 8.0

# %%
#2.Crea una tabla de correlación que muestre cómo se relacionan las variables price, 
# retail_price, units_sold, rating_sold, y rating_count. Interpreta los resultados y 
# discute si hay alguna correlación significativa entre estas variables.
df_ejercicio2 = pd.concat([" price", "retail_price", "units_sold", "rating_sold", "rating_count"],axis=1)
#df.groupby("education")["id"].count().reset_index()
#df_corr=df_ejercicio2.corr(method="spearman",numeric_only=True)
#df_corr
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 4
#       1 #2.Crea una tabla de correlación que muestre cómo se relacionan las variables price,
#       2 # retail_price, units_sold, rating_sold, y rating_count. Interpreta los resultados y
#       3 # discute si hay alguna correlación significativa entre estas variables.
# ----> 4 df_ejercicio2 = pd.concat([" price", "retail_price", "units_sold", "rating_sold", "rating_count"],axis=1)
#       5 #df.groupby("education")["id"].count().reset_index()
#       6 #df_corr=df_ejercicio2.corr(method="spearman",numeric_only=True)
#       7 #df_corr
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\reshape\concat.py:382, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
# ...

# %%
plt.figure(figsize=(30,30))
#Creamos una matriz booleana de mascara
mask = np.triu(np.ones_like(df_corr, dtype=bool))
sns.heatmap(df_corr,
            annot = True,
            fmt =".2f",
            cmap="magma",
            vmax=1,
            vmin=-1,
            mask=mask);
#Correlacion debil r < 0.3
#Correlacion moderada r de 0.3 a 0.7
#Correlacion fuerte r>0.7
