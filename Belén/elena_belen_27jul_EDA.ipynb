# %%
#Abrid el fichero de rating-and-performance con el método que sea más correcto.

#Mostrad las 10 últimas filas.

#Mostrad 5 filas aleatorias del DataFrame.

#¿Cuántas filas y columnas tenemos en el DataFrame?

#¿Cuáles son los nombres de las columnas del DataFrame?

#Seleccionad solo las columnas de tipo categórico del DataFrame. Después, mostrad los valores únicos y sus frecuencias para cada una de las columnas seleccionadas.

#En el DataFrame tenemos dos columnas que parece que nos dan la misma información "title" y "title_orig". Eliminad "title".

#¿En que columnas tenemos valores nulos? Utilizad el método que más os guste.

#¿Tenemos valores duplicados en el DataFrame?

# %%
import pandas as pd

# %%
#Abrid el fichero de rating-and-performance con el método que sea más correcto.

df = pd.read_csv("../rating_and_performance.csv", index_col=0)
df.head(2)
# Out:
#                                                    title  \
# index
# 0      2020 Summer Vintage Flamingo Print  Pajamas Se...
# 1      SSHOUSE Summer Casual Sleeveless Soirée Party ...
#
#                                               title_orig  price  retail_price  \
# index
# 0      2020 Summer Vintage Flamingo Print  Pajamas Se...   16.0            14
# 1       Women's Casual Summer Sleeveless Sexy Mini Dress    8.0            22
#
#       currency_buyer  units_sold  uses_ad_boosts  rating  rating_count  \
# index
# 0                EUR         100               0    3.76            54
# 1                EUR       20000               1    3.45          6135
#
#        rating_five_count  ...  merchant_rating_count  merchant_rating  \
# index                     ...
# 0                   26.0  ...                    568         4.128521
# 1                 2269.0  ...                  17752         3.899673
#
#                     merchant_id  merchant_has_profile_picture  \
# ...

# %%
#Mostrad las 10 últimas filas.

df.tail(10)
# Out:
#                                                    title  \
# index
# 1563   ZANZEA Femmes Été Polka Dot Kaftan Beach Club ...
# 1564   2018 Femme mode d'été en dentelle Patchwork Pa...
# 1565   Nouveau Pantalon De Mode D'été Femmes Leggings...
# 1566   Robe mi-longue d'été à manches courtes pour fe...
# 1567   Combinaison sans manches pour femmes couleur u...
# 1568   Nouvelle Mode Femmes Bohême Pissenlit Imprimer...
# 1569   10 couleurs femmes shorts d'été lacent ceintur...
# 1570   Nouveautés Hommes Siwmwear Beach-Shorts Hommes...
# 1571   Mode femmes d'été sans manches robes col en V ...
# 1572   Pantalon de yoga pour femmes à la mode Slim Fi...
#
#                                               title_orig  price  retail_price  \
# index
# 1563   ZANZEA Women Summer Polka Dot Kaftan Beach Clu...  15.00            92
# 1564   2018 Women fashion Summer Lace Patchwork Tank ...   5.91             5
# 1565   New Summer Fashion Trousers Women Leggings Rip...   3.00             8
# ...

# %%
#Mostrad 5 filas aleatorias del DataFrame.
df.sample(5)
# Out:
#                                                    title  \
# index
# 387    2020 Hommes Marque De Mode D'été Costumes D'ét...
# 36     Mode d'été femme papillon réservoir gilet sans...
# 100    6 Couleurs Automne Été Dames Casual Lâche Soli...
# 90     Summer Women Fashion Fashion Robe courte sans ...
# 1352   Nouveau été femmes mode pulls à manches courte...
#
#                                               title_orig  price  retail_price  \
# index
# 387    2020 Men Summer Fashion Brand Summer Suits Cas...   15.0            13
# 36     Summer fashion female butterfly tank vest slee...    8.0            17
# 100    6 Colors Autumn Summer Ladies Casual Loose Sol...    9.0             8
# 90     Summer Women Fashion Short Dress Sleeveless Wa...    8.0            51
# 1352   New Summer Women Fashion Pullovers Short Sleev...   11.0            83
#
#       currency_buyer  units_sold  uses_ad_boosts  rating  rating_count  \
# index
# ...

# %%
#¿Cuántas filas y columnas tenemos en el DataFrame?
df.shape
# Out:
# (1573, 43)

# %%
#¿Cuáles son los nombres de las columnas del DataFrame?
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1573 entries, 0 to 1572
# Data columns (total 43 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   title                         1573 non-null   object
#  1   title_orig                    1573 non-null   object
#  2   price                         1573 non-null   float64
#  3   retail_price                  1573 non-null   int64
#  4   currency_buyer                1573 non-null   object
#  5   units_sold                    1573 non-null   int64
#  6   uses_ad_boosts                1573 non-null   int64
#  7   rating                        1573 non-null   float64
#  8   rating_count                  1573 non-null   int64
#  9   rating_five_count             1528 non-null   float64
#  10  rating_four_count             1528 non-null   float64
#  11  rating_three_count            1528 non-null   float64
# ...

# %%
#Seleccionad solo las columnas de tipo categórico del DataFrame. Después, mostrad los valores únicos y 
# sus frecuencias para cada una de las columnas seleccionadas.
df.describe(include="object").T
# Out:
#                           count unique  \
# title                      1573   1201
# title_orig                 1573   1203
# currency_buyer             1573      1
# tags                       1573   1230
# product_color              1532    101
# product_variation_size_id  1559    106
# shipping_option_name       1573     15
# urgency_text                473      2
# origin_country             1556      6
# merchant_title             1573    958
# merchant_name              1569    957
# merchant_info_subtitle     1572   1058
# merchant_id                1573    958
# merchant_profile_picture    226    125
# product_url                1573   1341
# product_picture            1573   1341
# product_id                 1573   1341
# theme                      1573      1
# crawl_month                1573      1
#
#                                                                          top  \
# title                      Nouvelle mode d'été femmes robe décontractée c...
# ...

# %%
# Seleccionad solo las columnas de tipo categórico del DataFrame. 
# Después, mostrad los valores únicos y sus frecuencias para cada una de las columnas seleccionadas.


# df.select_dtypes(include=['object']).columns.tolist() 

# df.describe(include="object").T
# (df[column].value_counts()) 
# USANDO FOR 

#for ind, col in enumerate(df.columns[:4]):
#    print(ind, "--->", col)
#    print(df[col].unique())
#    print("-------------------")



# col_categoricas = df.select_dtypes(include=['object']).columns
# for col in col_categoricas:
 #   print(f"Columna '{col}':")
 #   print(df[col].value_counts())
  #  print(ind, "--->", col)
 #   print(df[col].unique())
 #   print("-------------------")

category_col = df.select_dtypes(include=['object']).columns

# Create a dictionary to store the number of unique values and their frequencies
unique_values_freq = {}

for col in category_col:
    unique_values = df[col].nunique()
    frequencies = df[col].value_counts()
    unique_values_freq[col] = {
        'num_unique': unique_values,
        'frequencies': frequencies
    }

# Print the result
for col, details in unique_values_freq.items():
    print(f"Column: {col}")
    print(f"Number of unique values: {details['num_unique']}")
    print("Frequencies:")
    print(details['frequencies'])
    print()
# Out:
# Column: title
# Number of unique values: 1201
# Frequencies:
# title
# Nouvelle mode d'été femmes robe décontractée col rond lâche Big Swing jupe sans manches Soild couleur robe de plage                                                                      24
# Mini robe de soirée décontractée sans manches pour femmes                                                                                                                                12
# Femmes d'été Sling Dress V-cou Floral Strap plissé Casual Pocket Large Dress                                                                                                              9
# Tissu taille formateur gilet chaud shaper été shaperwear minceur réglable sueur ceinture corps shaper                                                                                     9
# ...

# %%
#En el DataFrame tenemos dos columnas que parece que nos dan la misma información "title" y "title_orig". Eliminad "title".

df_dropTitle = df.drop(columns=['title'])
df_dropTitle.head(2)
# Out:
#                                               title_orig  price  retail_price  \
# index
# 0      2020 Summer Vintage Flamingo Print  Pajamas Se...   16.0            14
# 1       Women's Casual Summer Sleeveless Sexy Mini Dress    8.0            22
#
#       currency_buyer  units_sold  uses_ad_boosts  rating  rating_count  \
# index
# 0                EUR         100               0    3.76            54
# 1                EUR       20000               1    3.45          6135
#
#        rating_five_count  rating_four_count  ...  merchant_rating_count  \
# index                                        ...
# 0                   26.0                8.0  ...                    568
# 1                 2269.0             1027.0  ...                  17752
#
#        merchant_rating               merchant_id  \
# index
# 0             4.128521  595097d6a26f6e070cb878d1
# 1             3.899673  56458aa03a698c35c9050988
#
#        merchant_has_profile_picture  merchant_profile_picture  \
# ...

# %%
df.isna()
# Out:
#        title  title_orig  price  retail_price  currency_buyer  units_sold  \
# index
# 0      False       False  False         False           False       False
# 1      False       False  False         False           False       False
# 2      False       False  False         False           False       False
# 3      False       False  False         False           False       False
# 4      False       False  False         False           False       False
# ...      ...         ...    ...           ...             ...         ...
# 1568   False       False  False         False           False       False
# 1569   False       False  False         False           False       False
# 1570   False       False  False         False           False       False
# 1571   False       False  False         False           False       False
# 1572   False       False  False         False           False       False
#
#        uses_ad_boosts  rating  rating_count  rating_five_count  ...  \
# ...

# %%
#¿En que columnas tenemos valores nulos? Utilizad el método que más os guste.
df.isna().sum()[df.isna().sum()>0]
# Out:
# rating_five_count              45
# rating_four_count              45
# rating_three_count             45
# rating_two_count               45
# rating_one_count               45
# product_color                  41
# product_variation_size_id      14
# has_urgency_banner           1100
# urgency_text                 1100
# origin_country                 17
# merchant_name                   4
# merchant_info_subtitle          1
# merchant_profile_picture     1347
# dtype: int64

# %%
#¿En que columnas tenemos valores nulos? Utilizad el método que más os guste. 
# ¿CÓMO LO HARÍAMOS SI SUMATORIO?

# %%
#¿Tenemos valores duplicados en el DataFrame?
duplicados = df.duplicated().sum()
print(f'Este es el total de valores duplicados en el DataFrame: {duplicados} ')
# Out:
# Este es el total de valores duplicados en el DataFrame: 34
